# %% [markdown]
# <a href="https://colab.research.google.com/github/Kiritossss/Music-Recommendation-app---Capstone-term-2-/blob/main/Applied_machine_learning_Exercise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Importing Necessary Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2. Loading the Dataset

# %%
file_path = '/content/shopping_trends.csv'
data = pd.read_csv(file_path)

# first few rows
print("First few rows of the dataset:")
print(data.head())
# Out:
# First few rows of the dataset:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# 3. Examining the Dataset

# %%
# Check the dataset structure

print("\nDataset Info:")
print(data.info())

# Display basic statistics for numeric columns

print("\nDescriptive Statistics:")
print(data.describe())

# Check for missing values

print("\nMissing values in each column:")
print(data.isnull().sum())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %% [markdown]
# 4. Handling Missing Values

# %%
# Separate numeric and non-numeric columns
numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns
categorical_columns = data.select_dtypes(include=['object']).columns

# Fill missing values in numeric columns with their mean
data[numeric_columns] = data[numeric_columns].fillna(data[numeric_columns].mean())

# Fill missing values in categorical columns with the mode (most frequent value)
for col in categorical_columns:
    data[col] = data[col].fillna(data[col].mode()[0])

print("\nMissing values after handling:")
print(data.isnull().sum())
# Out:
# Missing values after handling:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# 5. Visualizing Missing Values

# %%
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.title("Heatmap of Missing Values")
plt.show()

# %% [markdown]
# 6. Exploring Numeric Columns

# %%
for col in numeric_columns:
    plt.figure(figsize=(8, 5))
    sns.histplot(data[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.show()

# %% [markdown]
# 7. Exploring Categorical Columns

# %%
for col in categorical_columns:
    plt.figure(figsize=(8, 5))
    sns.countplot(y=data[col], order=data[col].value_counts().index)
    plt.title(f"Countplot of {col}")
    plt.show()

# %% [markdown]
# 8. Correlation Analysis

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(data[numeric_columns].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# 9. Key Insights

# %%
print("\nKey Insights:\n")
print("1. The numeric columns in the dataset, including Age, Purchase Amount \n(USD), Review Rating, and Previous Purchases, offer valuable insights into \ncustomer behavior and demographics. Age ranges from 18 to 70, with an average \nof 44, while Purchase Amount (USD) varies between $20 and $100, with a mean \nof $59.76, indicating moderate variability. Review Rating reflects generally \npositive feedback, averaging 3.75, and Previous Purchases ranges from 1 to \n50, with an average of 25.35, showcasing a mix of new and frequent buyers. \nThese columns can be further analyzed through histograms to identify \ndistribution patterns and outliers, as well as correlation analysis to \nexplore relationships among numeric variables.\n")
print("2. Relationships between variables indicate that The categorical columns \nin the dataset, such as Gender, Category, Item Purchased, Location, Size, \nColor, Season, Payment Method, Shipping Type, Discount Applied, and \nSubscription Status, provide valuable insights into customer preferences and \npurchasing behavior. For example, analyzing Gender can reveal the proportion \nf male and female customers, while Category and Item Purchased can highlight \nthe most popular product types. Columns like Season can help identify \nseasonal trends, such as which products are purchased more during winter or \nspring. Similarly, Payment Method and Shipping Type can uncover customer \npreferences for payment and delivery options. \n\nAdvanced visualizations \nlike count plots or bar plots can help identify dominant values and \nimbalances in categories. For columns with high cardinality, such as \nLocation, analyzing the top contributing categories can simplify \ninterpretation. Relationships between categorical variables, such as how \nSeason impacts Category, or between categorical and numeric variables, like \naverage Purchase Amount (USD) by Payment Method, can provide deeper business \ninsights. These analyses collectively enable better understanding of customer \nsegmentation and behavior patterns.")
# Out:
# Key Insights:
#
# 1. The numeric columns in the dataset, including Age, Purchase Amount
# (USD), Review Rating, and Previous Purchases, offer valuable insights into
# customer behavior and demographics. Age ranges from 18 to 70, with an average
# of 44, while Purchase Amount (USD) varies between $20 and $100, with a mean
# of $59.76, indicating moderate variability. Review Rating reflects generally
# positive feedback, averaging 3.75, and Previous Purchases ranges from 1 to
# 50, with an average of 25.35, showcasing a mix of new and frequent buyers.
# These columns can be further analyzed through histograms to identify
# distribution patterns and outliers, as well as correlation analysis to
# explore relationships among numeric variables.
#
# 2. Relationships between variables indicate that The categorical columns
# in the dataset, such as Gender, Category, Item Purchased, Location, Size,
# Color, Season, Payment Method, Shipping Type, Discount Applied, and
# ...
